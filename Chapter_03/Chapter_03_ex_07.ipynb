# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from utilsforecast.plotting import plot_series 
from coreforecast.scalers import boxcox, boxcox_lambda
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(f'../DATA/aus_production.csv')
df['ds'] = pd.to_datetime(df['ds'])
df = df.tail(5*4).reset_index()
df.loc[15, 'Gas'] += 400

# %%
sns.lineplot(df, x='ds', y='Gas')
# Out:
# <Axes: xlabel='ds', ylabel='Gas'>

# %%
seasonal_decompose(x=df['Gas'], period=4).plot()

# %%
season = seasonal_decompose(df['Gas'], period=4).seasonal
sns.lineplot(df, x='ds', y=df['Gas'] - season)
# Out:
# <Axes: xlabel='ds', ylabel='None'>
